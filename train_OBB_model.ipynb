# %% [markdown]
# <a href="https://colab.research.google.com/github/stefanopisciella/smartCity/blob/main/train_OBB_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Controllo informazioni GPU

# %%
# !nvidia-smi
# Out:
# Sat May 11 10:44:07 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # Installazione YOLO

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.4/756.4 kB 4.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=train
# Out:
# WARNING ⚠️ 'model' argument is missing. Using default 'model=yolov8n.pt'.
# ...
# 100% 6.23M/6.23M [00:00<00:00, 83.2MB/s]
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8.yaml'.
# Ultralytics YOLOv8.2.12 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Download del dataset (che verrà usato per il training) in ambiente Colab

# %% [markdown]
# nel caso in cui il  dataset sia stato annotato usando roboflow: copiare ed incollare il code fornito da roboflow nella seguente casella di codice

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KPubIEEm8Zm5mF2TNJ2R")
project = rf.workspace("smartcity-1s7fz").project("cars-car-models-vscut")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # Training del custom model

# %%
import requests

url = 'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8x-obb.pt'
r = requests.get(url, allow_redirects=True)

open('YOLOv8x-obb.pt', 'wb').write(r.content)
# Out:
# 139533138

# %%
# !yolo task=detect mode=train model=YOLOv8x-obb.pt data=/content/Cars-Car-Models-1/data.yaml epochs=100 imgsz=640
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=obb' model. Ignoring 'task=detect' and updating to 'task=obb' to match model.
# Ultralytics YOLOv8.2.12 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Zippare la cartella di output (di nome out_folder) del processo di training

# %% [markdown]
# cd nella directory padre della cartella out_folder (eseguire sotto)

# %%
# Out:
# /content

# %%
# !zip -r out_folder.zip out_folder/
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/train_batch2.jpg (deflated 2%)
#   adding: runs/detect/train/train_batch91.jpg (deflated 8%)
#   adding: runs/detect/train/confusion_matrix_normalized.png (deflated 17%)
#   adding: runs/detect/train/results.csv (deflated 89%)
#   adding: runs/detect/train/labels.jpg (deflated 53%)
#   adding: runs/detect/train/confusion_matrix.png (deflated 17%)
#   adding: runs/detect/train/train_batch1.jpg (deflated 3%)
#   adding: runs/detect/train/args.yaml (deflated 53%)
#   adding: runs/detect/train/events.out.tfevents.1715424381.fe9fdbac8732.2515.0 (deflated 88%)
#   adding: runs/detect/train/P_curve.png (deflated 10%)
#   adding: runs/detect/train/weights/ (stored 0%)
#   adding: runs/detect/train/weights/last.pt (deflated 9%)
#   adding: runs/detect/train/weights/best.pt (deflated 9%)
#   adding: runs/detect/train/train_batch0.jpg (deflated 3%)
# ...

# %% [markdown]
# # Monta GoogleDrive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Copiare il .zip dell'output del training in Google Drive usando il comando bash "cp"

# %%
# !cp /content/runs.zip /content/drive/MyDrive/Robotica
